# %%
import pandas as pd
import matplotlib.pyplot as plt

# Ensure inline plotting for Jupyter notebooks
# %matplotlib inline

# %%
# Load the CSV file into a DataFrame
df = pd.read_csv('DemandTimeDistribution.csv')

# Display the first few rows of the DataFrame to ensure it loaded correctly
df.head()
# Out:
#    T       TTI
# 0  0  0.000007
# 1  1  0.000007
# 2  2  0.000007
# 3  3  0.000007
# 4  4  0.000007

# %%
def convert_seconds_to_time(seconds):
    hours = (seconds // 2400) % 24
    minutes = (seconds % 2400) // 40
    return f"{hours:02}:{minutes:02}"

tranT = [convert_seconds_to_time(t) for t in df['T']]

plt.figure(figsize=(16, 10))
plt.plot(tranT, df['TTI'])
plt.title('Distribution of Pro over T')
plt.xlabel('Time')
plt.ylabel('Pro')
plt.grid(True)

hours = [f"{h:02}:00" for h in range(25)]
plt.xticks(hours)

plt.show()
